# %% [markdown]
# Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %% [markdown]
# Read the excel file and drop all the rows with atleast one null value

# %%
dataset = pd.read_excel('file.xlsx')
dataset = dataset.dropna()
dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904  581587.0   22613.0          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905  581587.0   22899.0         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906  581587.0   23254.0        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907  581587.0   23255.0      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908  581587.0   22138.0        BAKING SET 9 PIECE RETROSPOT        3.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [406829 rows x 8 columns]

# %% [markdown]
# Customers who have made a transaction between 1st Dec 2010 to 31st Aug 2011

# %%
training_data = dataset[(dataset['InvoiceDate'] >= '2010-12-01') & (dataset['InvoiceDate'] <= '2011-08-31')]
training_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 319395  564852.0   82552.0                  WASHROOM METAL SIGN      10.0
# 319396  564852.0   21756.0             BATH BUILDING BLOCK WORD       3.0
# 319397  564852.0   21908.0        CHOCOLATE THIS WAY METAL SIGN       7.0
# 319398  564852.0   22116.0      METAL SIGN HIS DINNER IS SERVED      10.0
# 319399  564852.0   23091.0           ZINC HERB GARDEN CONTAINER       2.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 319395 2011-08-30 17:23:00       1.45     14976.0  United Kingdom
# 319396 2011-08-30 17:23:00       5.95     14976.0  United Kingdom
# 319397 2011-08-30 17:23:00       2.10     14976.0  United Kingdom
# 319398 2011-08-30 17:23:00       0.79     14976.0  United Kingdom
# 319399 2011-08-30 17:23:00       6.25     14976.0  United Kingdom
#
# [231183 rows x 8 columns]

# %% [markdown]
# Customers who have not made any subsequent purchase between Sep 2011 and Dec 2011

# %%
temp0_data = dataset[(dataset['InvoiceDate'] >= '2011-09-01') & (dataset['InvoiceDate'] <= '2011-12-31')]
temp0_data
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 320705  565080.0   20677.0               PINK POLKADOT BOWL       8.0
# 320706  565080.0   22128.0       PARTY CONES CANDY ASSORTED      24.0
# 320708  565082.0   22423.0         REGENCY CAKESTAND 3 TIER       2.0
# 320709  565082.0    15060B       FAIRY CAKE DESIGN UMBRELLA       8.0
# 320710  565082.0   23245.0       SET OF 3 REGENCY CAKE TINS       4.0
# ...          ...       ...                              ...       ...
# 541904  581587.0   22613.0      PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905  581587.0   22899.0     CHILDREN'S APRON DOLLY GIRL        6.0
# 541906  581587.0   23254.0    CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907  581587.0   23255.0  CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908  581587.0   22138.0    BAKING SET 9 PIECE RETROSPOT        3.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 320705 2011-09-01 08:25:00       1.25     13509.0  United Kingdom
# 320706 2011-09-01 08:25:00       1.25     13509.0  United Kingdom
# 320708 2011-09-01 09:15:00      12.75     13305.0  United Kingdom
# 320709 2011-09-01 09:15:00       3.75     13305.0  United Kingdom
# 320710 2011-09-01 09:15:00       4.95     13305.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
#
#  18222.0,
#  18223.0,
#  18225.0,
#  18226.0,
#  18228.0,
#  18229.0,
#  18230.0,
#  18232.0,
#  18235.0,
#  18236.0,
#  18237.0,
#  18240.0,
#  18241.0,
#  18242.0,
#  18245.0,
#  18246.0,
#  18249.0,
#  18251.0,
#  18252.0,
#  18255.0,
#  18257.0,
#  18259.0,
#  18261.0,
#  18263.0,
#  18265.0,
#  18270.0,
#  18272.0,
#  18273.0,
#  18274.0,
#  18276.0,
#  18277.0,
#  18278.0,
#  18282.0,
#  18283.0,
#  18287.0,
#  12347.0,
#  12348.0,
#  12349.0,
#  12352.0,
#  12356.0,
#  12357.0,
#  12358.0,
#  12359.0,
#  12360.0,
#  12362.0,
#  12364.0,
#  12367.0,
#  12370.0,
#  12371.0,
#  12372.0,
#  12374.0,
#  12375.0,
#  12379.0,
#  12380.0,
#  12381.0,
#  12384.0,
#  12388.0,
#  12390.0,
#  12391.0,
#  12393.0,
#  12394.0,
#  12395.0,
#  12397.0,
#  12398.0,
#  12403.0,
#  12406.0,
#  12407.0,
#  12408.0,
#  12409.0,
#  12412.0,
#  12413.0,
#  12415.0,
#  12417.0,
#  12420.0,
#  12421.0,
#  12422.0,
#  12423.0,
#  12425.0,
#  12427.0,
#  12428.0,
#  12429.0,
#  12430.0,
#  12431.0,
#  12432.0,
#  12433.0,
#  12434.0,
#  12435.0,
#  12436.0,
#  12437.0,
#  12438.0,
#  12442.0,
#  12444.0,
#  12445.0,
#  12446.0,
#  ...]

# %% [markdown]
# Create the labels for the customers from training_data

# %%
target_values = []
for customer_id in training_data['CustomerID']:
    if customer_id not in temp0_customer_ids:
        target_values.append('Churn')
    else:
        target_values.append('Not Churn')
training_data['Target'] = target_values
training_data
# Out:
# /var/folders/hz/r3x824916lx2gwqnf6vhdcc00000gp/T/ipykernel_57806/1019097770.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Target'] = target_values
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 319395  564852.0   82552.0                  WASHROOM METAL SIGN      10.0
# 319396  564852.0   21756.0             BATH BUILDING BLOCK WORD       3.0
# 319397  564852.0   21908.0        CHOCOLATE THIS WAY METAL SIGN       7.0
# 319398  564852.0   22116.0      METAL SIGN HIS DINNER IS SERVED      10.0
# 319399  564852.0   23091.0           ZINC HERB GARDEN CONTAINER       2.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country     Target
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom      Churn
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      Churn
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom      Churn
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      Churn
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      Churn
# ...                    ...        ...         ...             ...        ...
# 319395 2011-08-30 17:23:00       1.45     14976.0  United Kingdom  Not Churn
# 319396 2011-08-30 17:23:00       5.95     14976.0  United Kingdom  Not Churn
# 319397 2011-08-30 17:23:00       2.10     14976.0  United Kingdom  Not Churn
# 319398 2011-08-30 17:23:00       0.79     14976.0  United Kingdom  Not Churn
# 319399 2011-08-30 17:23:00       6.25     14976.0  United Kingdom  Not Churn
#
# [231183 rows x 9 columns]

# %% [markdown]
# Filter the attributes required for training the models

# %%
training_features = training_data[['Quantity', 'UnitPrice', 'Country', 'Target']]
training_features
# Out:
#         Quantity  UnitPrice         Country     Target
# 0            6.0       2.55  United Kingdom      Churn
# 1            6.0       3.39  United Kingdom      Churn
# 2            8.0       2.75  United Kingdom      Churn
# 3            6.0       3.39  United Kingdom      Churn
# 4            6.0       3.39  United Kingdom      Churn
# ...          ...        ...             ...        ...
# 319395      10.0       1.45  United Kingdom  Not Churn
# 319396       3.0       5.95  United Kingdom  Not Churn
# 319397       7.0       2.10  United Kingdom  Not Churn
# 319398      10.0       0.79  United Kingdom  Not Churn
# 319399       2.0       6.25  United Kingdom  Not Churn
#
# [231183 rows x 4 columns]

# %% [markdown]
# Assign labels to values from attributes 'Quantity' and 'UnitPrice'

# %%
temp0 = list(training_features['UnitPrice'].values)
mid0 = sum(temp0) / len(temp0)

temp1 = [i for i in temp0 if i < mid0]
temp2 = [i for i in temp0 if i >= mid0]
mid1 = sum(temp1) / len(temp1)
mid2 = sum(temp2) / len(temp2)

new_unitPrice = []
for unitPrice in temp0:
    if unitPrice < mid1:
        new_unitPrice.append('low')
    elif unitPrice > mid1 and unitPrice < mid2:
        new_unitPrice.append('medium')
    else:
        new_unitPrice.append('high')

# %%
temp0 = list(training_features['Quantity'].values)
mid0 = sum(temp0) / len(temp0)

temp1 = [i for i in temp0 if i < mid0]
temp2 = [i for i in temp0 if i >= mid0]
mid1 = sum(temp1) / len(temp1)
mid2 = sum(temp2) / len(temp2)

new_quantity = []
for quantity in temp0:
    if quantity < mid1:
        new_quantity.append('low')
    elif quantity > mid1 and unitPrice < mid2:
        new_quantity.append('medium')
    else:
        new_quantity.append('high')

# %%
training_features['UnitPrice'] = new_unitPrice
training_features['Quantity'] = new_quantity
# Out:
# /var/folders/hz/r3x824916lx2gwqnf6vhdcc00000gp/T/ipykernel_57806/3200418754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_features['UnitPrice'] = new_unitPrice
# /var/folders/hz/r3x824916lx2gwqnf6vhdcc00000gp/T/ipykernel_57806/3200418754.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_features['Quantity'] = new_quantity

# %% [markdown]
# Save the dataframe 'training_features' as csv file

# %%
training_features.to_csv('data.csv')

# %%
df = pd.read_csv('data.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#   Quantity UnitPrice         Country Target
# 0   medium    medium  United Kingdom  Churn
# 1   medium    medium  United Kingdom  Churn
# 2   medium    medium  United Kingdom  Churn
# 3   medium    medium  United Kingdom  Churn
# 4   medium    medium  United Kingdom  Churn

# %% [markdown]
# Split the dataframe into training and testing set

# %%
train_size = int(len(df) * 0.80)
train_size
# Out:
# 184946

# %%
train = df[:train_size]
test = df[train_size:]

# %% [markdown]
# Function for calculating the entropy of the entire or subset of the dataframe

# %%
def get_entropy_of_dataset(df):
    labels = df.iloc[:,-1].values
    distinct_labels = {}

    for label in labels:
        if label not in distinct_labels:
            distinct_labels[label] = 1
        else:
            distinct_labels[label] += 1

    entropy = 0
    length = len(labels)
    for distinct_label in distinct_labels:
        pi = distinct_labels[distinct_label] / length
        entropy += (-pi) * np.log2(pi)

    return entropy

# %% [markdown]
# Function for calculating the average information of a specific attribute

# %%
def get_avg_info_of_attribute(df, attribute):
    attribute_values = list(set(df[attribute].values))
    total_length = len(df)
    average_info = 0

    for attribute_value in attribute_values:
        temp_df = df[df[attribute] == attribute_value]
        entropy = get_entropy_of_dataset(temp_df)
        average_info += ((len(temp_df) / total_length) * entropy)

    return average_info

# %% [markdown]
# Function for calculating the Information gain of a specific attribute

# %%
def get_information_gain(df, attribute):
    return get_entropy_of_dataset(df) - get_avg_info_of_attribute(df, attribute)

# %% [markdown]
# Function for selecting an attribute with highest information gain

# %%
def get_selected_attribute(df):
    attributes = list(df.columns[:-1].values)
    igs = []
    
    for attribute in attributes:
        igs.append(get_information_gain(df, attribute))

    max_index = igs.index(max(igs))
    return attributes[max_index]

# %% [markdown]
# Function for creating the tree (Tree is created using the datatype 'dict')

# %%
def make_tree(df):
    if get_entropy_of_dataset(df) == 0:
        return ''.join(list(set(df.iloc[:,-1].values)))
    if len(df.columns.values) == 1:
        values = list(df.iloc[:,-1].values)
        return ''.join(list(max(values, key= lambda x : values.count(x))))
    if df.empty:
        return []
    tree = {}
    attribute = get_selected_attribute(df)
    attribute_values = list(set(df[attribute].values))
    
    tree[attribute] = {}
    for attribute_value in attribute_values:
        temp_df = df[df[attribute] == attribute_value]
        temp_df = temp_df.drop([attribute], axis = 1)
        tree[attribute][attribute_value] = make_tree(temp_df)

    return tree

# %% [markdown]
# Function for predicting the label of a given instance using the tree created.

# %%
def pred(tree, instance):
    sub_tree = tree
    while type(sub_tree) != str:
        attribute = list(sub_tree.keys())[0]
        attribute_value = instance[attribute]
        sub_tree = sub_tree[attribute][attribute_value]

    return sub_tree

# %% [markdown]
# Function for evaluating the accuracy of the decision tree.

# %%
def evaluate(tree, test):
    length = len(test)
    correct = 0

    for i in range(length):
        prediction = pred(tree, test.iloc[i])
        if prediction == test.iloc[i, -1]:
            correct += 1

    return (correct / length) * 100

# %% [markdown]
# Create the tree

# %%
tree = make_tree(train)
tree
# Out:
# {'Country': {'Norway': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Channel Islands': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}},
#     'low': {'Quantity': {'medium': 'Not Churn'}}}},
#   'Lebanon': 'Churn',
#   'Belgium': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Cyprus': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}},
#     'low': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}}}},
#   'Israel': 'Churn',
#   'European Community': 'Churn',
#   'Czech Republic': 'Not Churn',
#   'Japan': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Churn',
#       'high': 'Churn',
#       'low': 'Churn'}}}},
#   'Malta': 'Not Churn',
#   'Finland': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}},
#     'low': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}}}},
#   'Brazil': 'Churn',
#   'Austria': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': {'Quantity': {'medium': 'Not Churn', 'low': 'Churn'}},
#     'low': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}}}},
#   'Greece': 'Churn',
#   'Canada': 'Churn',
#   'Saudi Arabia': 'Churn',
#   'Portugal': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Unspecified': 'Churn',
#   'France': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Denmark': 'Not Churn',
#   'Germany': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}},
#     'low': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}}}},
#   'EIRE': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Australia': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': 'Not Churn',
#     'low': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}}}},
#   'Italy': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}},
#     'low': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}}}},
#   'Iceland': 'Not Churn',
#   'Netherlands': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'United Arab Emirates': 'Churn',
#   'Bahrain': 'Churn',
#   'Sweden': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Switzerland': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Singapore': 'Not Churn',
#   'USA': 'Churn',
#   'Poland': {'UnitPrice': {'medium': {'Quantity': {'medium': 'Not Churn',
#       'low': 'Not Churn'}},
#     'high': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}},
#     'low': {'Quantity': {'medium': 'Not Churn', 'low': 'Not Churn'}}}},
#   'United Kingdom': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}},
#   'Lithuania': 'Churn',
#   'Spain': {'Quantity': {'medium': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}},
#     'low': {'UnitPrice': {'medium': 'Not Churn',
#       'high': 'Not Churn',
#       'low': 'Not Churn'}}}}}}

# %% [markdown]
# Evaluate the tree

# %%
tree_accuracy = evaluate(tree, test)
tree_accuracy
# Out:
# 85.19583883037394

# %% [markdown]
# Decision Tree(ID3) Accuracy = 85.19

# %% [markdown]
# Training the ANN model

# %%
training_features = training_data[['Quantity', 'UnitPrice', 'Country', 'Target']]

# %%
le0 = LabelEncoder()
training_features['Country'] = le0.fit_transform(training_features['Country'])
le1 = LabelEncoder()
training_features['Target'] = le1.fit_transform(training_features['Target'])
# Out:
# /var/folders/hz/r3x824916lx2gwqnf6vhdcc00000gp/T/ipykernel_57806/1639887391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_features['Country'] = le0.fit_transform(training_features['Country'])
# /var/folders/hz/r3x824916lx2gwqnf6vhdcc00000gp/T/ipykernel_57806/1639887391.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_features['Target'] = le1.fit_transform(training_features['Target'])

# %%
x = training_features.iloc[:,:-1].values
y = training_features.iloc[:,-1].values
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
ann_model = Sequential()
ann_model.add(Dense(4, activation='relu'))
ann_model.add(Dense(10, activation='relu'))
ann_model.add(Dense(1, activation='sigmoid'))
# Out:
# 2022-11-09 09:02:23.652908: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
ann_model.compile(loss = 'mse', optimizer = 'adam', metrics=['accuracy'])
ann_model.fit(xtrain, ytrain, epochs = 1, batch_size = 1, verbose = 1)
# Out:
# 184946/184946 [==============================] - 123s 663us/step - loss: 0.1560 - accuracy: 0.8077

# %%
y_pred = ann_model.predict(xtest)
correct = 0
for i in range(len(y_pred)):
    if y_pred[i] > 0.50:
        y_pred[i] = 1
    else:
        y_pred[i] = 0
for i in range(len(y_pred)):
    if y_pred[i] == ytest[i]:
        correct += 1

ann_accuracy = (correct / len(y_pred)) * 100
ann_accuracy
# Out:
# 1445/1445 [==============================] - 1s 572us/step
# 80.70592815277809

# %% [markdown]
# ANN Model Accuracy = 80.7

# %% [markdown]
# Train the SVM model

# %%
svm_model = SVC(kernel='rbf')
svm_model.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
print(accuracy_score(ytest, svm_model.predict(xtest)))
# Out:
# 0.8070376538270216

# %% [markdown]
# SVM Model Accuracy = 80.70

# %% [markdown]
# Model Comparison (Accuracy)
# - Decision Tree = 85.19
# - ANN Model = 80.70
# - SVM Model = 80.70
